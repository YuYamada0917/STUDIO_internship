# %%
#必要なライブラリを呼ぶ
import pandas as pd
import numpy as np
from sklearn import linear_model

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#データセットの作成
list = []
for i in range(40, 130, 10):
  for j in range(40, 130, 10):
    for k in range(30, 50, 5):
      list += [[i, j, k]]

# %%
df = pd.DataFrame(list)
df.columns = ['t1', 't2', 't3']
df
# Out:
#       t1   t2  t3
# 0     40   40  30
# 1     40   40  35
# 2     40   40  40
# 3     40   40  45
# 4     40   50  30
# ..   ...  ...  ..
# 319  120  110  45
# 320  120  120  30
# 321  120  120  35
# 322  120  120  40
# 323  120  120  45
#
# [324 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/My Drive/to_csv_out.csv')

# %%
df = pd.read_csv('/content/drive/My Drive/to_csv_in.csv')

# %%
df
# Out:
#      Unnamed: 0   t1   t2  t3  readability  highlight  design  score1  score2
# 0             0   40   40  30            2          0       0       2       2
# 1             1   40   40  35            2          0       1       3       5
# 2             2   40   40  40            2          2       1       5       9
# 3             3   40   40  45            2          2       1       5       9
# 4             4   40   50  30            2          2       1       5       9
# ..          ...  ...  ...  ..          ...        ...     ...     ...     ...
# 319         319  120  110  45            3          0       3       6      12
# 320         320  120  120  30            1          0       1       2       4
# 321         321  120  120  35            2          0       1       3       5
# 322         322  120  120  40            3          0       2       5       9
# 323         323  120  120  45            3          0       3       6      12
#
# [324 rows x 9 columns]

# %%
X = df[['t1', 't2', 't3']]
y = df['score2']

# %%
#重回帰分析モデルの作成
reg = linear_model.LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
print(reg.coef_) #重み
print(reg.intercept_) #切片
# Out:
# [0.00222222 0.01736111 0.22864198]
# 0.1061728395061774
