# %%
import math
#カンマ区切りで入力を得る
w0, s0, w1, s1, w2, s2, w3, s3, w4, s4, w5, s5, w6, s6 = map(int, input().split())

t1 = s1
t2 = s3
t3 = s5

if (t1==t2 and t1 >= t3) or (t1==t3 and t1 >= t2) or (t2==t3 and t2 >= t1) :
  print("強調したい文章は何番目ですか")
  n = map(int,input())
  if (n == 1): #t1を強調
    t2 = 0.6754902*t1 - 1.6862745098039298
    t3 = 0.51470588*t1 - 1.5882352941176592
    w1 = 7
    #w3, w5 = 4
    w3 = 4
    w5 = 4
    if (t1 >= 60):
      s2 = 20
      s4 = 15
    else :
      s2 = 15
      s4 = 13

  elif (n == 2): #t2を強調
    t1 = 0.6754902*t2 - 1.6862745098039298
    t3 = 0.51470588*t2 - 1.5882352941176592
    w3 = 7
    #w1, w5 = 4
    w1 = 4
    w5 = 4
    if (t1 >= 60):
      s2 = 20
      s4 = 15
    else :
      s2 = 15
      s4 = 13

  elif (n == 3): #t3を強調
    t1 = 0.81037978*t3 + 2.192052980132452
    t2 = 0.81037978*t3 + 2.192052980132452 
    w5 = 7
    #w1, w3 = 4
    w1 = 4
    w3 = 4
    if (t3 >= 43):
      s2 = 20
      s4 = 20
    else :
      s2 = 15
      s4 = 15
  else:
    print(n, "番目の文章は存在しません。")

#t1を強調
elif (t1 > t2) and (t1 > t3) : 
  t2 = 0.6754902*t1 - 1.6862745098039298
  t3 = 0.51470588*t1 - 1.5882352941176592
  w1 = 7
  #w3, w5 = 4
  w3 = 4
  w5 = 4
  if (t1 >= 60):
    s2 = 20
    s4 = 15
  else :
    s2 = 15
    s4 = 13

#t2を強調
elif (t2 > t1) and (t2 > t3) :
  t1 = 0.6754902*t2 - 1.6862745098039298
  t3 = 0.51470588*t2 - 1.5882352941176592
  w3 = 7
  #w1, w5 = 4
  w1 = 4
  w5 = 4
  if (t2 >= 60):
    s2 = 20
    s4 = 15
  else :
    s2 = 15
    s4 = 13

#t3を強調
elif (t3 > t1) and (t3 > t2) :
  t1 = 0.81037978*t3 + 2.192052980132452
  t2 = 0.81037978*t3 + 2.192052980132452
  w5 = 7
  #w1, w3 = 4
  w1 = 4
  w3 = 4
  if (t3 >= 43):
    s2 = 20
    s4 = 20
  else :
    s2 = 15
    s4 = 15
else :
  print("error")

#int型に変形(小数点以下を切り捨て)
s1 = math.floor(t1)
s3 = math.floor(t2)
s5 = math.floor(t3)

print(w0, s0, w1, s1, w2, s2, w3, s3, w4, s4, w5, s5, w6, s6)
# Out:
# 0 180 7 120 0 36 4 32 0 24 4 34 0 180
# 0 180 7 120 0 20 4 79 0 15 4 60 0 180
